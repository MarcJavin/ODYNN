# %% [markdown]
# # Tutorial

# %% [markdown]
# ## Neuron simulation

# %%
import opthh.neursimul as sim
import scipy as sp

# %%
t = sp.arange(0., 1200., 0.1)
i = 40. * ((t > 400) & (t < 800))
sim.simul(dt=0.1, i_inj=i, show=True, save=False)
# Out:
# ___________Neuron Simulation____________
# Simulation time : 0.40208911895751953
# [array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#         1.1999e+03]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([-50.00025   , -50.00052424, -50.00082263, ..., -58.38738873,
#         -58.38801757, -58.38864613]),
#  array([9.99090909e-08, 1.00288788e-07, 1.02061056e-07, ...,
#         9.86900947e-01, 9.86004221e-01, 9.85108311e-01])]

# %% [markdown]
# ## Compare two sets of parameters

# %%
from opthh.hhmodel import DEFAULT, DEFAULT_2

# %%
DEFAULT
# Out:
# {'C_m': 20.0,
#  'E_Ca': 20.0,
#  'E_K': -60.0,
#  'E_L': -60.0,
#  'decay_ca': 110.0,
#  'e__mdp': -3.36,
#  'e__scale': 6.75,
#  'e__tau': 10.0,
#  'f__mdp': 25.2,
#  'f__scale': -5.03,
#  'f__tau': 151.0,
#  'g_Ca': 3.0,
#  'g_Kf': 0.07,
#  'g_Ks': 10.0,
#  'g_L': 0.005,
#  'h__alpha': 0.282,
#  'h__mdp': 6.42,
#  'h__scale': -1.0,
#  'n__mdp': 19.9,
#  'n__scale': 15.9,
#  'n__tau': 25.0,
#  'p__mdp': -8.05,
#  'p__scale': 7.43,
#  'p__tau': 100.0,
#  'q__mdp': -15.6,
#  'q__scale': -9.97,
#  'q__tau': 150.0,
#  'rho_ca': 0.23}

# %%
sim.comp_pars_targ(DEFAULT, DEFAULT_2, dt=0.1, i_inj=i, show=True)
# Out:
# Simulation time :  5.781099796295166

# %% [markdown]
# ## Compare more sets

# %%
from copy import copy

# %%
d1 = copy(DEFAULT)
d1['C_m'] = 100.
d2 = copy(DEFAULT)
d2['C_m'] = 10.
d3 = copy(DEFAULT)
d3['C_m'] = 1
sim.comp_pars([d1, d2, d3], dt=0.1, i_inj=i, show=True)
# Out:
# Simulation time :  5.872040510177612

# %%
d1 = copy(DEFAULT)
d1['g_Ca'] = 0.8
d2 = copy(DEFAULT)
d2['g_Ca'] = 1
d3 = copy(DEFAULT)
d3['g_Ca'] = 1.2
sim.comp_pars([d1, d2, d3], dt=0.1, i_inj=i, show=True)
# Out:
# Simulation time :  6.312694549560547
